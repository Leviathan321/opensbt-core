# %% [markdown]
# # Experiment Configuration and Execution
#
# In this tutorial we show how to configure and execute an experiment in OpenSBT to test an ADS Agent. We show the configuration of the experiment for the simulation of an agent in the DummySimulator (simplistic SUT & Simulation, no GPU required).

# %% [markdown]
# # Description Use Case
#
# The dummy simulations use case contains an AEB agent and another pedestrian. Both actors move linear, while pedestrian has a fixed trajectory and fixed velocity, the ego agent has a predefined path but can modife his velocity. I.e. he brakes when he detects other actors within a predefined range.
# We want to test the AEB agent in violating the safety distance of 1m. For this we want to vary the initial velocities of both actors as well the orientation of the pedestrian crossing the agents lane.
#
# In particlar, the pedestrian has a speed in the range of [0.2, 3] m/s, the ego [1, 10] m/s, while orientation range is [0,180] degrees.

# %% [markdown]
# ### Defining An Experiment
#
# To define an experiment we need to instantiate `ADASProblem`.
#
# ADASProblem holds:
#
# - the **scenario** - which can be an OpenSCENARIO file, or file of another format supported by simulator
# - the **search variables** - whose values are altered to produce (different) scenario througout the search
# - the **search space** represented by the lower and upper bounds as arrays
# - the **fitness function**
# - the **criticality function** - represents the safety requirements/testing oracle
# - the **simulate function** - the simulator is triggered via this function
# - the **simulator-related variables**, i.e., simulation time, sampling time, toggle for visualization
#
# Note, that for now the SUT is defined via the simulator functions, as we assume that the SUT is embedded into the simulator. We are working on an update where the SUT can be define uncoupled from the simulator.

# %%
cd opensbt-core
# Out:
# /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/opensbt-core

# %%
import os
from evaluation.fitness import *
from problem.adas_problem import ADASProblem
from problem.pymoo_test_problem import PymooTestProblem
from experiment.experiment_store import *
from algorithm.algorithm import *
from evaluation.critical import *
from simulation.dummy_simulation import DummySimulator


problem = ADASProblem(
                      problem_name="DummySimulatorProblem",
                      scenario_path="",
                      xl=[0, 1, 0, 1],
                      xu=[360, 3,360, 3],
                      simulation_variables=[
                          "orientation_ego",
                          "velocity_ego",
                          "orientation_ped",
                          "velocity_ped"],
                      fitness_function=FitnessMinDistanceVelocityFrontOnly(),
                      critical_function=CriticalAdasDistanceVelocity(),
                      simulate_function=DummySimulator.simulate,
                      simulation_time=10,
                      sampling_time=0.25
                      )

# %% [markdown]
# Now we want to find critical test for the defined problem. We have two options to execute the testing experiment: via console or via the code directly.
#
# To start search without console, we instantiate the optimizer class of our corresponding algorithm and can directly run the search. To write the results, we can pass to the corresponding writing method the optimization paramaters. The results will be written in the default folder name `results`. A different folder name can be also passed.

# %%
from algorithm.nsga2_optimizer import NsgaIIOptimizer

# Instantiate search algorithm
optimizer = NsgaIIOptimizer(
                            problem=problem,
                            config=DefaultSearchConfiguration()
                            )
# Run search
res = optimizer.run()

# Write results

res.write_results(params = optimizer.parameters)
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       20 |      1 |             - |             -
#      2 |       40 |      2 |  1.0000000000 |         ideal
#      3 |       60 |      3 |  0.0116637050 |         ideal
#      4 |       80 |      2 |  0.2403030042 |         ideal
#      5 |      100 |      2 |  0.4583160083 |         ideal
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 13
#       9 res = optimizer.run()
#      11 # Write results
# ---> 13 res.write_results(params = optimizer.parameters)
#
# AttributeError: 'Result' object has no attribute 'write_results'

# %% [markdown]
# ### Starting Search Using Console
#
# For this option as next step we need to create an `Experiment` instance, where we specify the algorithm to be used for the search and its configuration.
# The experiment requires following inputs:
#
# - the name
# - the created problem,
# - the search algorithm and
# - the search configuration
#
# Consider, the algorithm is an enumeration value which need to be registed beforehand via the algorithm.py script.

# %%
experiment = Experiment(name="6",
                        problem=problem,
                        algorithm=AlgorithmType.NSGAII,
                        search_configuration=DefaultSearchConfiguration())

# %% [markdown]
# Then we register the experiment so that we can use it later via console.

# %%
experiments_store.register(experiment)
# Out:
# 0

# %% [markdown]
# To start search via console we run the experiment with the name "1":

# %%
# !python run.py -e 6
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       20 |      1 |             - |             -
#      2 |       40 |      2 |  1.0138082141 |         ideal
#      3 |       60 |      2 |  0.000000E+00 |             f
#      4 |       80 |      3 |  0.5722516610 |         ideal
#      5 |      100 |      6 |  0.2455609548 |         ideal
#      6 |      120 |      6 |  0.1545722252 |         ideal
#      7 |      140 |      5 |  0.0154328861 |         ideal
#      8 |      160 |      7 |  0.0360417482 |         ideal
#      9 |      180 |      6 |  0.0370913184 |         ideal
#     10 |      200 |      8 |  0.0093639826 |         nadir
#     11 |      220 |      8 |  0.0167935814 |         ideal
#     12 |      240 |     11 |  0.0058044256 |         ideal
#     13 |      260 |     10 |  0.0518742484 |         ideal
#     14 |      280 |     10 |  0.0305115683 |         ideal
#     15 |      300 |     12 |  0.0147274054 |         ideal
#     16 |      320 |     13 |  0.0162316098 |         ideal
#     17 |      340 |     11 |  0.0088059931 |         ideal
#     18 |      360 |     12 |  0.0089275326 |         ideal
#     19 |      380 |     13 |  0.0056855853 |         nadir
#     20 |      400 |     15 |  0.0255730518 |             f
# ^C

# %% [markdown]
# We can change the experiment parameter as e.g., lower and upper bounds of the search parameters and the search time by using flags:

# %%
# !python run.py -e 6 -min 0 0 -max 10 2 -m  "FinalHostSpeed" "PedestrianSpeed" -t "00:01:00"
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       20 |      1 |             - |             -
#      2 |       40 |      2 |  1.0000000000 |         ideal
#      3 |       60 |      4 |  0.1086623463 |         ideal
#      4 |       80 |      2 |  0.7832789683 |         ideal
#      5 |      100 |      4 |  0.4235488821 |         ideal
#      6 |      120 |      4 |  0.0101674571 |         ideal
#      7 |      140 |      4 |  0.9722123655 |         ideal
#      8 |      160 |      5 |  0.4425256429 |         ideal
#      9 |      180 |      6 |  0.0734665186 |             f
#     10 |      200 |      4 |  0.0188390144 |         ideal
#     11 |      220 |      6 |  0.0230092956 |         ideal
#     12 |      240 |      6 |  0.6808938002 |         ideal
#     13 |      260 |      4 |  0.0069664414 |         ideal
#     14 |      280 |      6 |  0.0518090465 |         ideal
#     15 |      300 |      7 |  0.0049988859 |         ideal
#     16 |      320 |      8 |  0.0091837406 |         ideal
#     17 |      340 |      9 |  0.0035674613 |         ideal
#     18 |      360 |      5 |  0.0087711322 |         ideal
#     19 |      380 |      7 |  0.0147863252 |             f
#     20 |      400 |      7 |  0.1460536657 |         nadir
#     21 |      420 |     10 |  0.0100400926 |         ideal
#     22 |      440 |      7 |  0.0151611185 |             f
#     23 |      460 |      7 |  0.0397556008 |         nadir
#     24 |      480 |     11 |  0.0108358249 |         ideal
#     25 |      500 |     13 |  0.0055920741 |             f
#     26 |      520 |     12 |  0.0019094060 |             f
#     27 |      540 |     12 |  0.0131434046 |         nadir
#     28 |      560 |     11 |  0.1011511270 |         nadir
#     29 |      580 |     10 |  0.0221193485 |         nadir
#     30 |      600 |      4 |  0.1881618613 |         ideal
#     31 |      620 |      5 |  0.0422841934 |         ideal
#     32 |      640 |      6 |  0.0318400216 |         nadir
#     33 |      660 |      9 |  0.0584960238 |         ideal
#     34 |      680 |     10 |  0.0264010630 |         ideal
#     35 |      700 |     11 |  0.0009977884 |             f
#     36 |      720 |     11 |  0.0390550128 |         ideal
#     37 |      740 |     12 |  0.3282252844 |         ideal
#     38 |      760 |     11 |  0.0157290760 |         ideal
#     39 |      780 |     10 |  0.0500023205 |         ideal
#     40 |      800 |     11 |  0.0020718275 |             f
#     41 |      820 |     12 |  0.0067606909 |         nadir
#     42 |      840 |     15 |  0.5247022468 |         ideal
#     43 |      860 |     15 |  0.0058966611 |             f
#     44 |      880 |     15 |  0.0005611850 |             f
#     45 |      900 |     19 |  0.0020147975 |             f
#     46 |      920 |     19 |  0.0048221250 |             f
#     47 |      940 |     15 |  0.0099787798 |             f
#     48 |      960 |     19 |  0.0028517586 |         ideal
#     49 |      980 |     19 |  0.0000257151 |             f
#     50 |     1000 |     20 |  0.0042011876 |             f
#     51 |     1020 |     20 |  0.0018983435 |             f
#     52 |     1040 |     20 |  0.0021898707 |             f
#     53 |     1060 |     20 |  0.0135759933 |             f
#     54 |     1080 |     20 |  0.0009964687 |             f
#     55 |     1100 |     20 |  0.0020510992 |             f
#     56 |     1120 |     20 |  0.0028077436 |             f
#     57 |     1140 |     18 |  0.0034646964 |             f
#     58 |     1160 |     19 |  0.0108021339 |         nadir
#     59 |     1180 |     20 |  0.0152759003 |             f
#     60 |     1200 |     20 |  0.0014817052 |             f
#     61 |     1220 |     20 |  0.0060603239 |         nadir
#     62 |     1240 |     20 |  0.0013381099 |             f
#     63 |     1260 |     20 |  0.0101196002 |             f
#     64 |     1280 |     20 |  0.0012238923 |             f
#     65 |     1300 |     18 |  0.0104340378 |             f
#     66 |     1320 |     18 |  0.000000E+00 |             f
#     67 |     1340 |     18 |  0.0040491728 |         nadir
#     68 |     1360 |     19 |  0.0047487267 |             f
#     69 |     1380 |     20 |  0.0031213090 |         nadir
#     70 |     1400 |     20 |  0.0010351854 |             f
#     71 |     1420 |     20 |  0.0060698661 |         ideal
#     72 |     1440 |     20 |  0.2355833844 |         ideal
#     73 |     1460 |     20 |  0.0073070243 |         nadir
#     74 |     1480 |     14 |  0.0401200498 |         ideal
#     75 |     1500 |     14 |  0.0084407841 |         nadir
#     76 |     1520 |     14 |  0.0063477974 |         ideal
#     77 |     1540 |     14 |  0.0042087346 |             f
#     78 |     1560 |     12 |  0.0524917826 |             f
#     79 |     1580 |     13 |  0.0286528039 |         ideal
#     80 |     1600 |     15 |  0.7015610684 |         nadir
#     81 |     1620 |     15 |  0.0127389900 |         nadir
#     82 |     1640 |     11 |  0.0286818875 |             f
#     83 |     1660 |     12 |  0.0266082352 |         ideal
#     84 |     1680 |     18 |  0.0510452360 |         ideal
#     85 |     1700 |     20 |  0.0703621048 |         nadir
#     86 |     1720 |     18 |  0.0060687929 |             f
#     87 |     1740 |     14 |  0.0074130361 |         ideal
#     88 |     1760 |     15 |  0.0204376495 |         ideal
#     89 |     1780 |     15 |  0.0276142290 |         nadir
#     90 |     1800 |     16 |  0.0964828442 |         nadir
#     91 |     1820 |     17 |  0.0841214466 |         ideal
#     92 |     1840 |     18 |  0.0225715103 |         nadir
#     93 |     1860 |     18 |  0.000000E+00 |             f
#     94 |     1880 |     11 |  0.0067100740 |         ideal
#     95 |     1900 |     12 |  0.0096691198 |         ideal
#     96 |     1920 |     15 |  0.0025641789 |         ideal
#     97 |     1940 |     16 |  0.0677800047 |         nadir
#     98 |     1960 |     14 |  0.0260085838 |         ideal
#     99 |     1980 |     14 |  0.0167402788 |         nadir
#    100 |     2000 |     13 |  0.0809067735 |         nadir
#    101 |     2020 |     14 |  0.1548117089 |         nadir
#    102 |     2040 |     12 |  0.9151342653 |         nadir
#    103 |     2060 |     13 |  0.0166623097 |             f
#    104 |     2080 |     13 |  0.0046811966 |             f
#    105 |     2100 |     13 |  0.000000E+00 |             f
#    106 |     2120 |     14 |  0.0194100197 |         ideal
#    107 |     2140 |     16 |  0.0032873082 |             f
#    108 |     2160 |     17 |  0.0502879082 |         nadir
#    109 |     2180 |     17 |  0.0053614752 |             f
#    110 |     2200 |     16 |  0.1764242081 |         nadir
#    111 |     2220 |     17 |  0.4484404448 |         nadir
#    112 |     2240 |     19 |  0.0027140839 |             f
#    113 |     2260 |     18 |  0.2310042802 |         nadir
#    114 |     2280 |     18 |  0.0007460807 |             f
#    115 |     2300 |     14 |  1.5820199627 |         nadir
#    116 |     2320 |     15 |  0.2679107671 |         nadir
#    117 |     2340 |     16 |  0.2767228313 |         nadir
#    118 |     2360 |     17 |  0.0181617881 |         nadir
#    119 |     2380 |     17 |  0.0029733374 |             f
#    120 |     2400 |     17 |  0.000000E+00 |             f
#    121 |     2420 |     18 |  0.0026305839 |             f
#    122 |     2440 |     13 |  1.1434335913 |         nadir
#    123 |     2460 |     15 |  0.0470938302 |         nadir
#    124 |     2480 |     16 |  0.0334117466 |         ideal
#    125 |     2500 |     18 |  0.0034823590 |             f
#    126 |     2520 |     17 |  0.0264907476 |         nadir
#    127 |     2540 |     13 |  0.0039139196 |             f
#    128 |     2560 |     12 |  0.0005487087 |             f
#    129 |     2580 |     12 |  0.0160266965 |             f
#    130 |     2600 |     12 |  0.000000E+00 |             f
#    131 |     2620 |     12 |  0.0010337936 |             f
#    132 |     2640 |     11 |  0.0050456283 |             f
#    133 |     2660 |     12 |  0.0114911811 |             f
#    134 |     2680 |     12 |  0.0270212219 |         nadir
#    135 |     2700 |     13 |  0.0151267686 |             f
#    136 |     2720 |     12 |  0.0562108975 |         nadir
#    137 |     2740 |     12 |  0.000000E+00 |             f
#    138 |     2760 |     12 |  0.000000E+00 |             f
#    139 |     2780 |     12 |  0.000000E+00 |             f
#    140 |     2800 |     12 |  0.0001112360 |             f
#    141 |     2820 |     12 |  0.0001112360 |             f
#    142 |     2840 |     13 |  0.0036881240 |             f
#    143 |     2860 |     13 |  0.000000E+00 |             f
#    144 |     2880 |     13 |  0.0023039264 |             f
#    145 |     2900 |     12 |  0.0033835445 |             f
#    146 |     2920 |     12 |  0.0381848263 |             f
#    147 |     2940 |     12 |  0.000000E+00 |             f
#    148 |     2960 |     14 |  0.0059647205 |             f
#    149 |     2980 |     14 |  0.000000E+00 |             f
#    150 |     3000 |     14 |  0.000000E+00 |             f
#    151 |     3020 |     15 |  0.0003559179 |             f
#    152 |     3040 |     15 |  0.0003559179 |             f
#    153 |     3060 |     16 |  0.8016032113 |         nadir
#    154 |     3080 |     16 |  0.5629188996 |         nadir
#    155 |     3100 |     17 |  0.9465538716 |         nadir
#    156 |     3120 |     17 |  0.000000E+00 |             f
#    157 |     3140 |     17 |  0.1880098451 |         nadir
#    158 |     3160 |     17 |  0.000000E+00 |             f
#    159 |     3180 |     17 |  1.5232110816 |         nadir
#    160 |     3200 |     16 |  0.0051517214 |             f
#    161 |     3220 |     17 |  0.0020361680 |             f
#    162 |     3240 |     17 |  0.5827833981 |         nadir
#    163 |     3260 |     17 |  0.0018325238 |             f
#    164 |     3280 |     17 |  0.0027779478 |             f
#    165 |     3300 |     17 |  0.000000E+00 |             f
#    166 |     3320 |     18 |  0.0290069789 |         nadir
#    167 |     3340 |     19 |  0.0026178998 |             f
#    168 |     3360 |     18 |  0.0070893247 |         nadir
#    169 |     3380 |     18 |  0.000000E+00 |             f
#    170 |     3400 |     18 |  0.000000E+00 |             f
#    171 |     3420 |     18 |  0.0022109464 |             f
#    172 |     3440 |     18 |  0.0023259046 |             f
#    173 |     3460 |     18 |  0.0023259046 |             f
#    174 |     3480 |     17 |  0.0034640558 |             f
#    175 |     3500 |     18 |  0.0046808804 |             f
#    176 |     3520 |     18 |  0.000000E+00 |             f
#    177 |     3540 |     18 |  0.1007074031 |         nadir
#    178 |     3560 |     18 |  0.000000E+00 |             f
#    179 |     3580 |     18 |  0.0009025555 |             f
#    180 |     3600 |     19 |  0.0114175545 |             f
#    181 |     3620 |     19 |  0.0004739262 |             f
#    182 |     3640 |     19 |  0.0008080404 |             f
#    183 |     3660 |     20 |  0.6092973247 |         nadir
#    184 |     3680 |     20 |  0.5271505716 |         nadir
#    185 |     3700 |     20 |  0.4467012433 |         nadir
#    186 |     3720 |     20 |  0.000000E+00 |             f
#    187 |     3740 |     20 |  8.785550E-06 |             f
#    188 |     3760 |     20 |  0.0011551173 |             f
#    189 |     3780 |     20 |  0.0138426152 |         nadir
#    190 |     3800 |     19 |  2.4573449192 |         nadir
#    191 |     3820 |     20 |  0.0055035201 |             f
#    192 |     3840 |     19 |  0.0001765916 |             f
#    193 |     3860 |     19 |  0.0016901925 |             f
#    194 |     3880 |     19 |  0.0016901925 |             f
#    195 |     3900 |     19 |  0.0016901925 |             f
#    196 |     3920 |     19 |  0.0059631173 |             f
#    197 |     3940 |     19 |  0.0000850026 |             f
#    198 |     3960 |     15 |  0.0024922180 |             f
#    199 |     3980 |     16 |  0.0028018559 |             f
#    200 |     4000 |     18 |  0.0190535958 |             f
#    201 |     4020 |     18 |  0.0015034156 |             f
#    202 |     4040 |     19 |  0.0021430889 |             f
#    203 |     4060 |     18 |  0.0018482493 |             f
#    204 |     4080 |     18 |  0.0018482493 |             f
#    205 |     4100 |     19 |  0.0063443955 |             f
#    206 |     4120 |     19 |  0.000000E+00 |             f
#    207 |     4140 |     19 |  0.0006930956 |             f
#    208 |     4160 |     20 |  0.0046531684 |             f
#    209 |     4180 |     20 |  0.0031734465 |             f
#    210 |     4200 |     20 |  0.0014343052 |             f
#    211 |     4220 |     20 |  0.0003768560 |             f
#    212 |     4240 |     20 |  0.0003768560 |             f
#    213 |     4260 |     20 |  0.0484749304 |         nadir
#    214 |     4280 |     20 |  0.0022991310 |             f
#    215 |     4300 |     20 |  0.0034945844 |             f
#    216 |     4320 |     20 |  0.0014609225 |             f
#    217 |     4340 |     20 |  0.0014609225 |             f
#    218 |     4360 |     20 |  0.0040839477 |             f
#    219 |     4380 |     20 |  0.2520432822 |         nadir
#    220 |     4400 |     20 |  0.0509326067 |         nadir
#    221 |     4420 |     20 |  0.000000E+00 |             f
#    222 |     4440 |     19 |  0.0008732833 |             f
#    223 |     4460 |     19 |  0.0013492482 |             f
#    224 |     4480 |     19 |  0.0016731380 |             f
#    225 |     4500 |     20 |  0.0058707065 |             f
#    226 |     4520 |     20 |  0.0008707034 |             f
#    227 |     4540 |     20 |  0.0005864747 |             f
#    228 |     4560 |     20 |  0.0045545863 |         nadir
#    229 |     4580 |     19 |  0.0832969942 |         nadir
#    230 |     4600 |     19 |  0.0197724578 |         nadir
#    231 |     4620 |     19 |  0.000000E+00 |             f
#    232 |     4640 |     20 |  0.0017445018 |             f
#    233 |     4660 |     20 |  0.0017445018 |             f
#    234 |     4680 |     20 |  0.0025431573 |             f
#    235 |     4700 |     19 |  0.1616884513 |         nadir
#    236 |     4720 |     19 |  0.000000E+00 |             f
#    237 |     4740 |     18 |  0.0112009102 |         nadir
#    238 |     4760 |     18 |  0.0005431066 |             f
#    239 |     4780 |     17 |  0.0557986412 |         nadir
#    240 |     4800 |     17 |  0.000000E+00 |             f
#    241 |     4820 |     17 |  0.000000E+00 |             f
#    242 |     4840 |     17 |  0.000000E+00 |             f
#    243 |     4860 |     17 |  0.000000E+00 |             f
#    244 |     4880 |     17 |  0.0023946580 |             f
#    245 |     4900 |     17 |  0.0023946580 |             f
#    246 |     4920 |     17 |  0.0023946580 |             f
#    247 |     4940 |     17 |  0.0023946580 |             f
#    248 |     4960 |     18 |  0.0048814188 |             f
#    249 |     4980 |     18 |  0.000000E+00 |             f
#    250 |     5000 |     15 |  0.0013191644 |             f
#    251 |     5020 |     15 |  0.0026321515 |             f
#    252 |     5040 |     16 |  0.0058095936 |             f
#    253 |     5060 |     17 |  0.0043898896 |             f
#    254 |     5080 |     17 |  0.000000E+00 |             f
#    255 |     5100 |     17 |  0.000000E+00 |             f
#    256 |     5120 |     17 |  0.0024059367 |             f
#    257 |     5140 |     18 |  0.0046458240 |             f
#    258 |     5160 |     18 |  0.000000E+00 |             f
#    259 |     5180 |     18 |  0.0030448730 |             f
#    260 |     5200 |     20 |  0.0072795911 |             f
#    261 |     5220 |     20 |  0.000000E+00 |             f
#    262 |     5240 |     20 |  0.000000E+00 |             f
#    263 |     5260 |     20 |  0.0013455308 |             f
#    264 |     5280 |     19 |  0.0030655579 |             f
#    265 |     5300 |     19 |  0.000000E+00 |             f
#    266 |     5320 |     20 |  0.0020176072 |             f
#    267 |     5340 |     20 |  0.0020176072 |             f
#    268 |     5360 |     20 |  0.0066082439 |             f
#    269 |     5380 |     20 |  0.0001940993 |             f
#    270 |     5400 |     20 |  0.0001940993 |             f
#    271 |     5420 |     20 |  0.0001940993 |             f
#    272 |     5440 |     17 |  0.0027651145 |             f
#    273 |     5460 |     19 |  0.0029238389 |             f
#    274 |     5480 |     19 |  0.000000E+00 |             f
#    275 |     5500 |     19 |  0.0008268841 |             f
#    276 |     5520 |     17 |  0.0008336278 |             f
#    277 |     5540 |     17 |  0.0008336278 |             f
#    278 |     5560 |     18 |  0.1639619599 |         nadir
#    279 |     5580 |     18 |  0.000000E+00 |             f
# ^C
# Traceback (most recent call last):
#   File "run.py", line 182, in <module>
#     res = optimizer.run()
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/opensbt-core/algorithm/optimizer.py", line 20, in run
#     return minimize(self.problem,
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages/pymoo/optimize.py", line 67, in minimize
#     res = algorithm.run()
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages/pymoo/core/algorithm.py", line 141, in run
#     self.next()
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages/pymoo/core/algorithm.py", line 161, in next
#     self.evaluator.eval(self.problem, infills, algorithm=self)
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages/pymoo/core/evaluator.py", line 69, in eval
#     self._eval(problem, pop[I], evaluate_values_of, **kwargs)
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages/pymoo/core/evaluator.py", line 90, in _eval
#     out = problem.evaluate(X, return_values_of=evaluate_values_of, return_as_dictionary=True, **kwargs)
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/opensbt-core/model_ga/problem.py", line 168, in evaluate
#     _out = self.do(X, return_values_of, *args, **kwargs)
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages/pymoo/core/problem.py", line 229, in do
#     self._evaluate_vectorized(X, out, *args, **kwargs)
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages/pymoo/core/problem.py", line 237, in _evaluate_vectorized
#     self._evaluate(X, out, *args, **kwargs)
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/opensbt-core/problem/adas_problem.py", line 88, in _evaluate
#     simout_list = self.simulate_function(x, self.simulation_variables, self.scenario_path, sim_time=self.simulation_time,
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/opensbt-core/simulation/dummy_simulation.py", line 29, in simulate
#     simout = DummySimulator.simulate_single(ind,
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/opensbt-core/simulation/dummy_simulation.py", line 107, in simulate_single
#     real_ego_traj = np.append(real_ego_traj, new_state, axis = 1)
#   File "<__array_function__ internals>", line 200, in append
#   File "/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages/numpy/lib/function_base.py", line 5499, in append
#     return concatenate((arr, values), axis=axis)
#   File "<__array_function__ internals>", line 200, in concatenate
# KeyboardInterrupt

# %% [markdown]
# The complete list of flags is available (here)[].
