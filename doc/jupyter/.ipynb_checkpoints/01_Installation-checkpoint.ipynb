# %% [markdown]
# # Installation
#
# In this tutorial we show how to install OpenSBT and execute a dummy AEB system in a simplified simulator.
#
# The installation has been tested with Ubuntu 22.04 and Python 3.7. It is recommend having installed git.
#
# With git you need first to open a terminal in the folder where you want to install OpenSBT and clone the repository via (the "!" is only required if executed in this jupyter notebook))

# %%
# !git clone https://git.fortiss.org/opensbt/opensbt-core.git
# Out:
# Cloning into 'opensbt-core'...
# remote: Enumerating objects: 1590, done.
# remote: Counting objects: 100% (269/269), done.
# remote: Compressing objects: 100% (266/266), done.
# remote: Total 1590 (delta 156), reused 0 (delta 0), pack-reused 1321
# Receiving objects: 100% (1590/1590), 89.18 MiB | 1.32 MiB/s, done.
# Resolving deltas: 100% (854/854), done.

# %% [markdown]
# Now you need to go to the OpenSBT folder via:

# %%
cd opensbt-core
# Out:
# /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/opensbt-core

# %%
and install all dependencies of OpenSBT with the following command (installation might take some seconds, as libraries need to be downloaded):

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: deap in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: numpy in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (1.24.4)
# Requirement already satisfied: scipy in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.10.1)
# Requirement already satisfied: matplotlib in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (3.7.3)
# Requirement already satisfied: pydotplus in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: graphviz in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.20.1)
# Requirement already satisfied: docker in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (6.1.3)
# Requirement already satisfied: pandas in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (2.0.3)
# Requirement already satisfied: setuptools in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (68.2.0)
# Requirement already satisfied: scikit-learn in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: pymoo in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (0.6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 4)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 4)) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 4)) (6.1.0)
# Requirement already satisfied: requests>=2.26.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from docker->-r requirements.txt (line 7)) (2.31.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from docker->-r requirements.txt (line 7)) (2.0.6)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from docker->-r requirements.txt (line 7)) (1.6.4)
# Requirement already satisfied: pytz>=2020.1 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 8)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 8)) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 10)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 10)) (3.2.0)
# Requirement already satisfied: autograd>=1.4 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from pymoo->-r requirements.txt (line 11)) (1.6.2)
# Requirement already satisfied: cma==3.2.2 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from pymoo->-r requirements.txt (line 11)) (3.2.2)
# Requirement already satisfied: alive-progress in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from pymoo->-r requirements.txt (line 11)) (3.1.4)
# Requirement already satisfied: dill in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from pymoo->-r requirements.txt (line 11)) (0.3.7)
# Requirement already satisfied: Deprecated in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from pymoo->-r requirements.txt (line 11)) (1.2.14)
# Requirement already satisfied: future>=0.15.2 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from autograd>=1.4->pymoo->-r requirements.txt (line 11)) (0.18.3)
# Requirement already satisfied: zipp>=3.1.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 4)) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from requests>=2.26.0->docker->-r requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from requests>=2.26.0->docker->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from requests>=2.26.0->docker->-r requirements.txt (line 7)) (2023.7.22)
# Requirement already satisfied: about-time==4.2.1 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from alive-progress->pymoo->-r requirements.txt (line 11)) (4.2.1)
# Requirement already satisfied: grapheme==0.6.0 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from alive-progress->pymoo->-r requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/venv/lib/python3.8/site-packages (from Deprecated->pymoo->-r requirements.txt (line 11)) (1.15.0)

# %%
pwd
# Out:
# '/home/sorokin/Projects/testing/search-based-test-case-generation/doc/jupyter/opensbt-core'

# %% [markdown]
# The install script will create a virtual environment and install all python dependencies inside the virtual enivornment
# .
# Afterwards it will switch to the virtual environment.
#
# We can now test the installation by running our first experiment: Testing a simplified Automated Emergency Braking system in avoiding a collision with a pedestrian. (Note: Only linear motion planning, no comprehensive vehicles dynamics or environmental simulation is used. This system is just for testing the installation of OpenSBT.)
# We need to run the first experiment which is already defined in OpenSBT for this. Note, that this is a very simplified system and is only for explaining the usage of OpenSBT.

# %%
from importlib import reload
import logging
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%I:%M:%S')

# %% [markdown]
# # Testing installation

# %%
# !python run.py -e 5
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       20 |      2 |             - |             -
#      2 |       40 |      2 |  0.1586601428 |         ideal
#      3 |       60 |      4 |  0.8217251251 |         ideal
#      4 |       80 |      5 |  0.4183117895 |         ideal
#      5 |      100 |      5 |  0.1392109441 |         ideal
#      6 |      120 |      3 |  0.3200840201 |         nadir
#      7 |      140 |      2 |  2.6043721633 |         nadir
#      8 |      160 |      2 |  1.0000000000 |         ideal
#      9 |      180 |      3 |  0.9634985267 |         ideal
#     10 |      200 |      3 |  9.0840445274 |         nadir
#     11 |      220 |      4 |  0.2204625844 |         ideal
#     12 |      240 |      4 |  0.4204739486 |         ideal
#     13 |      260 |      5 |  0.0963066215 |             f
#     14 |      280 |      6 |  0.1526638168 |         ideal
#     15 |      300 |      6 |  0.000000E+00 |             f
#     16 |      320 |      6 |  0.0079925709 |             f
#     17 |      340 |      6 |  0.1312615300 |         ideal
#     18 |      360 |      3 |  0.0566103297 |         ideal
#     19 |      380 |      5 |  0.1825821659 |         nadir
#     20 |      400 |      5 |  0.1659762068 |         nadir

# %% [markdown]
# When the experiment execution has been completed, following console output shall have been produced (n_nds and eps numbers might differ as search is randomized).
#
# ```bash showLineNumbers
# 2023-10-04 00:01:35,657 INFO     Logging setup. Writing to file:  ./log.txt
# 2023-10-04 00:01:35,659 INFO     Selected experiment: 5
# 2023-10-04 00:01:35,660 INFO     Pymoo NSGA-II algorithm is used.
# 2023-10-04 00:01:35,665 INFO     Running evaluation number 1
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       20 |      2 |             - |             -
# 2023-10-04 00:01:35,747 INFO     Running evaluation number 2
#      2 |       40 |      2 |  6.7749230680 |         nadir
# 2023-10-04 00:01:35,827 INFO     Running evaluation number 3
#      3 |       60 |      2 |  0.000000E+00 |             f
# 2023-10-04 00:01:35,918 INFO     Running evaluation number 4
#      4 |       80 |      2 |  0.000000E+00 |             f
# 2023-10-04 00:01:35,995 INFO     Running evaluation number 5
#      5 |      100 |      2 |  0.0063369374 |         ideal
# 2023-10-04 00:01:36,114 INFO     Running evaluation number 6
#      6 |      120 |      3 |  0.1152399423 |             f
# 2023-10-04 00:01:36,175 INFO     Running evaluation number 7
#      7 |      140 |      2 |  0.1381785040 |         ideal
# 2023-10-04 00:01:36,239 INFO     Running evaluation number 8
#      8 |      160 |      4 |  0.0860965917 |             f
# 2023-10-04 00:01:36,301 INFO     Running evaluation number 9
#      9 |      180 |      3 |  0.7258862023 |         ideal
# 2023-10-04 00:01:36,373 INFO     Running evaluation number 10
#     10 |      200 |      4 |  0.1785650172 |         ideal
# 2023-10-04 00:01:36,467 INFO     Running evaluation number 11
#     11 |      220 |      5 |  0.2091108772 |             f
# 2023-10-04 00:01:36,559 INFO     Running evaluation number 12
#     12 |      240 |      4 |  0.0211540214 |         ideal
# 2023-10-04 00:01:36,641 INFO     Running evaluation number 13
#     13 |      260 |      3 |  0.1154057918 |             f
# 2023-10-04 00:01:36,704 INFO     Running evaluation number 14
#     14 |      280 |      4 |  0.4956124364 |         nadir
# 2023-10-04 00:01:36,777 INFO     Running evaluation number 15
#     15 |      300 |      4 |  0.0225090584 |         ideal
# 2023-10-04 00:01:36,844 INFO     Running evaluation number 16
#     16 |      320 |      5 |  0.2735872394 |         ideal
# 2023-10-04 00:01:36,910 INFO     Running evaluation number 17
#     17 |      340 |      5 |  0.0577729987 |             f
# 2023-10-04 00:01:36,980 INFO     Running evaluation number 18
#     18 |      360 |      3 |  0.8866473485 |         ideal
# 2023-10-04 00:01:37,055 INFO     Running evaluation number 19
#     19 |      380 |      4 |  0.9434378203 |         ideal
# 2023-10-04 00:01:37,121 INFO     Running evaluation number 20
#     20 |      400 |      2 |  0.5037086835 |         ideal
# 2023-10-04 00:01:37,210 INFO     =====[NSGA2] Writing results to:
# 2023-10-04 00:01:37,211 INFO     /home/sorokin/Projects/testing/search-based-test-case-generation/results/DummySimulatorProblem/NSGA2/04-10-2023_00-01-37/
# 2023-10-04 00:01:47,503 INFO     ====== Algorithm search time: 1.55 sec

# %% [markdown]
# We can now inspect the created result artefacts which are located in the results folder whose path is written in the bottom of the output. We load them in the jupyter notebook:

# %%
import pandas as pd
import os
results_path = os.getcwd() + "/results/DummySimulatorProblem/NSGA2/12-10-2023_00-08-00"
df = pd.read_csv(f'{results_path}/all_critical_testcases.csv')
print(df)
# Out:
#     Index  orientation_ego  velocity_ego  orientation_ped  velocity_ped  \
# 0       0        92.087273      2.995708       166.990718      1.261997
# 1       1        92.087273      2.995708       166.990718      1.261997
# 2       2        92.087273      2.995708       166.990718      1.261997
# 3       3        91.894271      2.995708       167.114120      1.262659
# 4       4        92.087273      2.995708       166.990718      1.261997
# ..    ...              ...           ...              ...           ...
# 95     95       103.627753      2.999848       206.676171      2.845086
# 96     96        92.086910      2.995708       167.111987      1.262631
# 97     97       104.359155      2.999187       206.843582      2.908522
# 98     98       103.799135      2.999848       206.676171      2.877945
# 99     99       103.596072      2.999331       206.838176      2.865224
#
#     Fitness_Min distance  Fitness_Velocity at min distance
# 0               0.053056                         -2.995708
# 1               0.053056                         -2.995708
# 2               0.053056                         -2.995708
# 3               0.063576                         -2.995708
# 4               0.053056                         -2.995708
# ..                   ...                               ...
# 95              0.250421                         -2.999848
# 96              0.060624                         -2.995708
# 97              0.240846                         -2.999187
# 98              0.271858                         -2.999848
# 99              0.246238                         -2.999331
#
# [100 rows x 7 columns]

# %%
import pandas as pd
import os
results_path = os.getcwd() + "/results/DummySimulatorProblem/NSGA2/12-10-2023_00-08-00"
df = pd.read_csv(f'{results_path}/all_critical_testcases.csv')
print(df)
# Out:
#     Index  orientation_ego  velocity_ego  orientation_ped  velocity_ped  \
# 0       0        92.087273      2.995708       166.990718      1.261997
# 1       1        92.087273      2.995708       166.990718      1.261997
# 2       2        92.087273      2.995708       166.990718      1.261997
# 3       3        91.894271      2.995708       167.114120      1.262659
# 4       4        92.087273      2.995708       166.990718      1.261997
# ..    ...              ...           ...              ...           ...
# 95     95       103.627753      2.999848       206.676171      2.845086
# 96     96        92.086910      2.995708       167.111987      1.262631
# 97     97       104.359155      2.999187       206.843582      2.908522
# 98     98       103.799135      2.999848       206.676171      2.877945
# 99     99       103.596072      2.999331       206.838176      2.865224
#
#     Fitness_Min distance  Fitness_Velocity at min distance
# 0               0.053056                         -2.995708
# 1               0.053056                         -2.995708
# 2               0.053056                         -2.995708
# 3               0.063576                         -2.995708
# 4               0.053056                         -2.995708
# ..                   ...                               ...
# 95              0.250421                         -2.999848
# 96              0.060624                         -2.995708
# 97              0.240846                         -2.999187
# 98              0.271858                         -2.999848
# 99              0.246238                         -2.999331
#
# [100 rows x 7 columns]

# %% [markdown]
# Also we can inspect the visulization of the scenarios:

# %%
from IPython.display import Image
import os
n = 3 # show max n images
folder_gifs = results_path + os.sep + "gif"
i = 0
for f in os.listdir(folder_gifs):
    # checking if it is a file
    fpath = folder_gifs + os.sep + f
    if os.path.isfile(fpath) and i < n:
      img = Image(filename=fpath, width=300, height=300)
      display(img)
      i = i+1

# %% [markdown]
# Also we can inspect pair-wise test input space plots which are generated for all test cases encountered during search:

# %%
from IPython.display import Image
import os
n = 3 # show max n images
folder_gifs = results_path + os.sep + "design_space"
i = 0
for f in os.listdir(folder_gifs):
    # checking if it is a file
    fpath = folder_gifs + os.sep + f
    if os.path.isfile(fpath) and os.path.splitext(fpath)[1] == '.png' and  i < n:
      img = Image(filename=fpath, width=500, height=500)
      display(img)
      i = i+1
